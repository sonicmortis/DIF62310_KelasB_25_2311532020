# %% [markdown]
# <a href="https://colab.research.google.com/github/sonicmortis/DIF62310_KelasB_25_2311532020/blob/main/Praktikum%203/BernoulliNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import library dasar yang akan digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Load dataset yang linknya didapatkan dari github

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sonicmortis/DIF62310_KelasB_25_2311532020/refs/heads/main/Dataset/amazon_alexa.tsv', sep='\t')

# %% [markdown]
# lihat kolom dan isinya sebanyak 10 baris

# %%
df.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# ...

# %% [markdown]
# Melihat informasi dataset dan kolom dan memeriksa apakah ada missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            3150 non-null   int64
#  1   date              3150 non-null   object
#  2   variation         3150 non-null   object
#  3   verified_reviews  3149 non-null   object
#  4   feedback          3150 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 123.2+ KB

# %% [markdown]
# melihat ringkasan statistik masing-masing kolom numerik

# %%
df.describe()
# Out:
#             rating     feedback
# count  3150.000000  3150.000000
# mean      4.463175     0.918413
# std       1.068506     0.273778
# min       1.000000     0.000000
# 25%       4.000000     1.000000
# 50%       5.000000     1.000000
# 75%       5.000000     1.000000
# max       5.000000     1.000000

# %% [markdown]
# mengecek nilai null masing-masing kolom

# %%
df.isnull().sum()
# Out:
# rating              0
# date                0
# variation           0
# verified_reviews    1
# feedback            0
# dtype: int64

# %% [markdown]
# menghapus baris yang terdapat nilai null

# %%
df =  df.dropna()

# %% [markdown]
# membagi kolom kolom menjadi features dalam X dan label dalam y

# %%
X = df[['rating', 'variation', 'verified_reviews']]
y = df['feedback']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df["variation"] = label_encoder.fit_transform(df["variation"])

# %%
from sklearn.feature_extraction.text import CountVectorizer
import scipy.sparse as sp

vectorizer = CountVectorizer(binary=True)
X_train_text = vectorizer.fit_transform(X_train["verified_reviews"])
X_test_text = vectorizer.transform(X_test["verified_reviews"])

# Pastikan kolom variation sudah dalam bentuk numerik
label_encoder = LabelEncoder()
X_train["variation"] = label_encoder.fit_transform(X_train["variation"])
X_test["variation"] = label_encoder.transform(X_test["variation"])

# Pastikan semua nilai numerik
X_train[["rating", "variation"]] = X_train[["rating", "variation"]].astype(float)
X_test[["rating", "variation"]] = X_test[["rating", "variation"]].astype(float)

# Mengubah fitur numerik menjadi sparse matrix
X_train_numeric = sp.csr_matrix(X_train[["rating", "variation"]].values)
X_test_numeric = sp.csr_matrix(X_test[["rating", "variation"]].values)

# Menggabungkan fitur numerik dan teks
X_train_combined = sp.hstack((X_train_numeric, X_train_text))
X_test_combined = sp.hstack((X_test_numeric, X_test_text))

# %%
from sklearn.naive_bayes import BernoulliNB

model = BernoulliNB()
model.fit(X_train_combined, y_train)
# Out:
# BernoulliNB()

# %%
y_pred = model.predict(X_test_combined)
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi model: {accuracy:.2f}")
# Out:
# Akurasi model: 0.89
